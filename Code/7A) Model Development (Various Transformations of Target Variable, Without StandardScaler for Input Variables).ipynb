# %% [markdown]
# ### The plan is to train 3 models of increasing complexity. All 3 models will be trained without the use of StandardScaler.
# #### Model 1: Uses temporal and consumption features.
# #### Model 2: Adds weather features to Model 1.
# #### Model 3: Adds household, pricing, attitudinal, behavioural, and appliance features to Model 2.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
from sklearn.metrics import make_scorer

df = pd.read_csv('6) daily_consumption_data_full.csv', parse_dates=['date'])

# %%
# Categorisation of input variables
weather_features = [
    'temp_max', 'humidity_min', 'humidity_max', 'windspeed_max', 'precip_sum', 'solarradiation_sum',
    'humidity_at_peak_consumption', 'windspeed_at_peak_consumption', 'precip_at_peak_consumption', 
    'solarradiation_at_peak_consumption', 'temp_range', 'windspeed_min'
]

temporal_features = [
    'is_winter', 'is_summer', 'is_autumn', 'is_weekend', 'is_holiday', 'day_of_week_sin', 
    'day_of_week_cos', 'week_of_month_sin', 'week_of_month_cos'
]

consumption_features = [
    'consumption_sum', 'consumption_peak', 'consumption_min', 'prev_day_peak', 'same_day_last_week_peak', 
    'avg_peak_3d', 'avg_peak_7d', 'max_peak_7d', 'max_peak_3d'
]

household_features = [
    'household_size', 'male_occupants', 'female_occupants', 'count_children', 'ownership_owned', 
    'ownership_rented', 'ownership_other', 'work_from_home', 'housing_house', 'housing_apartment', 
    'count_rooms', 'electric_central_heating', 'heating_manual_boiler', 'heating_thermostatic_valves', 
    'heating_auto_set_times', 'heating_auto_temp_control', 'heating_not_sure', 'uses_electric_heater'
]

pricing_features = [
    'prop_low_price', 'prop_high_price', 'tariff_at_peak_consumption'
]

attitudinal_and_behavioural_features = [
    'interest_in_renewable_energy', 'interest_in_microgeneration', 'climate_change_concern', 
    'lifestyle_environment', 'smart_meter_bill_understanding', 'smart_meter_consumption_understanding'
]

appliance_features = [
    'washing_machine_fixed_schedule', 'tumble_dryer_fixed_schedule', 'dishwasher_fixed_schedule', 
    'immersion_water_heater_fixed_schedule', 'electric_oven_fixed_schedule', 'electric_hob_fixed_schedule', 
    'ironing_fixed_schedule', 'electric_shower_fixed_schedule', 'kettle_fixed_schedule', 'lighting_fixed_schedule', 
    'electric_heater_fixed_schedule', 'washer-dryer_combined_timer_use', 'washing_machine_timer_use', 
    'tumble_dryer_timer_use', 'dishwasher_timer_use', 'electric_space_heating_timer_use', 
    'washer-dryer_combined_ownership', 'washing_machine_ownership', 'tumble_dryer_ownership', 'dishwasher_ownership', 
    'electric_space_heating_ownership', 'count_low_efficiency_bulbs', 'total_refrigeration_units', 
    'count_cooking_appliances', 'count_laundry_appliances', 'count_kitchen_appliances', 
    'count_heating_water_appliances', 'count_entertainment_devices', 'count_computing_devices', 'count_tv', 
    'tv_energy_score'
]

# Define feature sets for models
model_1_features = temporal_features + consumption_features
model_2_features = model_1_features + weather_features
model_3_features = model_2_features + household_features + pricing_features + attitudinal_and_behavioural_features + appliance_features

# %% [markdown]
# ### Let's take a look at our target variable again

# %%
# Plot histogram of 'consumption_peak_next_day'
plt.figure(figsize=(10, 5))
plt.hist(df['consumption_peak_next_day'], bins=30, edgecolor='k', alpha=0.7)
plt.title('Histogram of Consumption Peak Next Day')
plt.xlabel('Consumption Peak Next Day')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Let's apply some transformation as the target variable is skewed

# %%
transformations = {
    'log_consumption_peak_next_day': np.log1p,
    'sqrt_consumption_peak_next_day': np.sqrt,
    'cbrt_consumption_peak_next_day': np.cbrt
}

for new_col, func in transformations.items():
    df[new_col] = func(df['consumption_peak_next_day'])

# Plot histograms of original and transformed 'consumption_peak_next_day'
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Original data
axes[0, 0].hist(df['consumption_peak_next_day'], bins=30, edgecolor='k', alpha=0.7)
axes[0, 0].set_title('Histogram of Next Day Peak Consumption')
axes[0, 0].set_xlabel('Next Day Peak Consumption')
axes[0, 0].set_ylabel('Frequency')

# Transformed data
for ax, (new_col, _) in zip(axes.flat[1:], transformations.items()):
    transformation_name = new_col.split('_')[0]
    ax.hist(df[new_col], bins=30, edgecolor='k', alpha=0.7)
    ax.set_title(f'Histogram of Next Day Peak Consumption ({transformation_name} transformed)')
    ax.set_xlabel(f'Next Day Peak Consumption ({transformation_name} transformed)')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Let's train our models using each transformation of the target variable, consumption_peak_next_day

# %%
# Define the hyperparameter grid
param_grid = {
    'n_estimators': randint(100, 3000),
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.29),
    'subsample': uniform(0.5, 0.5),
    'colsample_bytree': uniform(0.5, 0.5),
    'min_child_weight': randint(1, 10),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 1),
    'reg_lambda': uniform(0, 1)
}

# Define date ranges for folds
# Considering we only have 2013 data, we will define the folds as the following and use December as the test set
folds = [
    ('2013-01-08', '2013-08-31', '2013-09-01', '2013-09-30'),
    ('2013-01-08', '2013-09-30', '2013-10-01', '2013-10-31'),
    ('2013-01-08', '2013-10-31', '2013-11-01', '2013-11-30')
]

# %%
def run_model(features, df, folds, param_grid, model_name):
    def create_dataset(df, start_date, end_date):
        mask = (df['date'] >= pd.to_datetime(start_date)) & (df['date'] <= pd.to_datetime(end_date))
        X = df.loc[mask, features]
        y = df.loc[mask, ['consumption_peak_next_day', 'log_consumption_peak_next_day', 
                          'sqrt_consumption_peak_next_day', 'cbrt_consumption_peak_next_day']]
        return X, y

    def calculate_metrics(y_true, y_pred, transformation='consumption_peak_next_day'):
        if transformation == 'log_consumption_peak_next_day':
            y_true, y_pred = np.expm1(y_true), np.expm1(y_pred)
        elif transformation == 'sqrt_consumption_peak_next_day':
            y_true, y_pred = y_true ** 2, y_pred ** 2
        elif transformation == 'cbrt_consumption_peak_next_day':
            y_true, y_pred = y_true ** 3, y_pred ** 3
        
        mae = np.mean(np.abs(y_true - y_pred))
        
        non_zero = (y_true != 0)
        mape = np.mean(np.abs((y_true[non_zero] - y_pred[non_zero]) / y_true[non_zero])) * 100
        
        wape = np.sum(np.abs(y_true - y_pred)) / np.sum(np.abs(y_true)) * 100
        
        return mae, mape, wape
    
    # Custom function for WAPE to use as the scoring metric for the RandomSearch
    def wape_score(y_true, y_pred):
        return np.sum(np.abs(y_true - y_pred)) / np.sum(np.abs(y_true))

    wape_scorer = make_scorer(wape_score, greater_is_better=False)

    def get_best_params(best_params_list, wape_scores_val):
        best_fold_index = np.argmin(wape_scores_val)
        return best_params_list[best_fold_index]

    results = {target: {'mae_scores_train': [], 'mape_scores_train': [], 'wape_scores_train': [],
                        'mae_scores_val': [], 'mape_scores_val': [], 'wape_scores_val': [],
                        'feature_importances': [], 'best_params': []} 
               for target in ['consumption_peak_next_day', 'log_consumption_peak_next_day', 
                              'sqrt_consumption_peak_next_day', 'cbrt_consumption_peak_next_day']}

    print(f"\n--- Running {model_name} ---\n")

    for fold, (train_start, train_end, val_start, val_end) in enumerate(folds, 1):
        print(f"Fold {fold}")
        print(f"Training period: {train_start} to {train_end}")
        print(f"Validation period: {val_start} to {val_end}")
        
        X_train, y_train = create_dataset(df, train_start, train_end)
        X_val, y_val = create_dataset(df, val_start, val_end)
        
        tscv = TimeSeriesSplit(n_splits=3)
        
        for target in ['consumption_peak_next_day', 'log_consumption_peak_next_day', 
                       'sqrt_consumption_peak_next_day', 'cbrt_consumption_peak_next_day']:
            print(f"\nTarget: {target}")
            
            model = XGBRegressor(objective='reg:squarederror', n_jobs=16, enable_categorical=True)
            random_search = RandomizedSearchCV(model, param_distributions=param_grid, 
                                               n_iter=100, cv=tscv.split(X_train), 
                                               scoring=wape_scorer, 
                                               n_jobs=-1, random_state=1)
            random_search.fit(X_train, y_train[target])
            
            best_model = random_search.best_estimator_
            best_params = random_search.best_params_
            results[target]['best_params'].append(best_params)
            
            train_predictions = best_model.predict(X_train)
            train_mae, train_mape, train_wape = calculate_metrics(y_train[target], train_predictions, target)
            results[target]['mae_scores_train'].append(train_mae)
            results[target]['mape_scores_train'].append(train_mape)
            results[target]['wape_scores_train'].append(train_wape)
            
            val_predictions = best_model.predict(X_val)
            val_mae, val_mape, val_wape = calculate_metrics(y_val[target], val_predictions, target)
            results[target]['mae_scores_val'].append(val_mae)
            results[target]['mape_scores_val'].append(val_mape)
            results[target]['wape_scores_val'].append(val_wape)
            
            importances = best_model.feature_importances_
            results[target]['feature_importances'].append(dict(zip(features, importances)))
            
            print(f"Training metrics for fold {fold}:")
            print(f"MAE: {train_mae:.4f}")
            print(f"MAPE: {train_mape:.4f}%")
            print(f"WAPE: {train_wape:.4f}%")
            
            print(f"Validation metrics for fold {fold}:")
            print(f"MAE: {val_mae:.4f}")
            print(f"MAPE: {val_mape:.4f}%")
            print(f"WAPE: {val_wape:.4f}%")
            
            print("Top 15 Feature importances:")
            for feature, importance in sorted(zip(features, importances), key=lambda x: x[1], reverse=True)[:15]:
                print(f"{feature}: {importance:.3f}")
            print("\n")

    for target in ['consumption_peak_next_day', 'log_consumption_peak_next_day', 
                   'sqrt_consumption_peak_next_day', 'cbrt_consumption_peak_next_day']:
        print(f"\nResults for {target}:")
        print(f"Average Training MAE across folds: {np.mean(results[target]['mae_scores_train']):.4f}")
        print(f"Average Training MAPE across folds: {np.mean(results[target]['mape_scores_train']):.4f}%")
        print(f"Average Training WAPE across folds: {np.mean(results[target]['wape_scores_train']):.4f}%")
        print(f"Average Validation MAE across folds: {np.mean(results[target]['mae_scores_val']):.4f}")
        print(f"Average Validation MAPE across folds: {np.mean(results[target]['mape_scores_val']):.4f}%")
        print(f"Average Validation WAPE across folds: {np.mean(results[target]['wape_scores_val']):.4f}%")

        avg_importances = {}
        for feature in features:
            avg_importances[feature] = np.mean([fold[feature] for fold in results[target]['feature_importances']])

        print("\nTop 15 Average feature importances across folds:")
        for feature, importance in sorted(avg_importances.items(), key=lambda x: x[1], reverse=True)[:15]:
            print(f"{feature}: {importance:.3f}")

    test_start = '2013-12-01'
    test_end = '2013-12-30'

    X_train_final, y_train_final = create_dataset(df, df['date'].min(), pd.to_datetime(test_start) - pd.Timedelta(days=1))
    X_test, y_test = create_dataset(df, test_start, test_end)

    final_models = {}
    test_metrics = {}
    final_importances = {}

    for target in ['consumption_peak_next_day', 'log_consumption_peak_next_day', 
                   'sqrt_consumption_peak_next_day', 'cbrt_consumption_peak_next_day']:
        best_params = get_best_params(results[target]['best_params'], results[target]['wape_scores_val'])
        final_model = XGBRegressor(**best_params, enable_categorical=True)
        final_model.fit(X_train_final, y_train_final[target])

        test_predictions = final_model.predict(X_test)
        test_mae, test_mape, test_wape = calculate_metrics(y_test[target], test_predictions, target)
        print(f"\nMetrics on test set for {target}:")
        print(f"MAE: {test_mae:.4f}")
        print(f"MAPE: {test_mape:.4f}%")
        print(f"WAPE: {test_wape:.4f}%")

        final_models[target] = final_model
        test_metrics[target] = {'mae': test_mae, 'mape': test_mape, 'wape': test_wape}
        final_importances[target] = dict(zip(features, final_model.feature_importances_))

        feature_imp = pd.DataFrame(sorted(zip(final_model.feature_importances_, features)), columns=['Value','Feature'])

        plt.figure(figsize=(10, min(20, len(features) * 0.3)))
        plt.barh(feature_imp['Feature'], feature_imp['Value'])
        plt.title(f'XGBoost Feature Importances - {model_name} - {target} (Trained on All Data Excluding Test Set)')
        plt.xlabel('Importance')

        for i, v in enumerate(feature_imp['Value']):
            plt.text(v, i, f' {v:.3f}', va='center')

        plt.tight_layout()
        plt.show()

    return final_models, test_metrics, final_importances

# %%
# Dictionary to store results
all_results = {}

# Run models 1 to 3
for i, features in enumerate([model_1_features, model_2_features, model_3_features], 1):
    model_name = f"Model {i}"
    final_models, test_metrics, final_importances = run_model(features, df, folds, param_grid, model_name)
    all_results[model_name] = {
        'features': features,
        'test_metrics': test_metrics,
        'importances': final_importances
    }

# Let's also train model 4, which only uses the top 15 features from model 3
model_4_features = [feature for feature, importance in sorted(all_results['Model 3']['importances']['consumption_peak_next_day'].items(), key=lambda x: x[1], reverse=True)[:15]]
model_4, metrics_4, importances_4 = run_model(model_4_features, df, folds, param_grid, "Model 4 (Only Top 15 Features from Model 3)")

all_results["Model 4"] = {
    'features': model_4_features,
    'test_metrics': metrics_4,
    'importances': importances_4
}

# Compare the models
print("\n--- Model Comparison ---")
for model_name, results in all_results.items():
    print(f"\n{model_name}:")
    print(f"Number of features: {len(results['features'])}")
    for target, metrics in results['test_metrics'].items():
        print(f"\nTest metrics for {target}:")
        print(f"  MAE: {metrics['mae']:.4f}")
        print(f"  MAPE: {metrics['mape']:.4f}%")
        print(f"  WAPE: {metrics['wape']:.4f}%")
    
    print("\nTop 15 Feature Importances:")
    for target in ['consumption_peak_next_day', 'log_consumption_peak_next_day', 
                   'sqrt_consumption_peak_next_day', 'cbrt_consumption_peak_next_day']:
        if target in results['importances']:
            print(f"\n{target}:")
            importances = results['importances'][target]
            sorted_importances = sorted(importances.items(), key=lambda x: x[1], reverse=True)[:15]
            for feature, importance in sorted_importances:
                print(f"{feature}: {importance:.3f}")
# Out:
# --- Running Model 1 ---
#
# Fold 1
# Training period: 2013-01-08 to 2013-08-31
# Validation period: 2013-09-01 to 2013-09-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3331
# MAPE: 56.6426%
# WAPE: 29.7236%
# Validation metrics for fold 1:
# MAE: 0.3372
# MAPE: 63.8490%
# WAPE: 33.2061%
# Top 15 Feature importances:
# avg_peak_7d: 0.460
# avg_peak_3d: 0.220
# max_peak_7d: 0.072
# max_peak_3d: 0.060
# consumption_sum: 0.039
# consumption_peak: 0.026
# same_day_last_week_peak: 0.021
# prev_day_peak: 0.015
# day_of_week_sin: 0.014
# is_winter: 0.011
# consumption_min: 0.010
# is_summer: 0.009
# day_of_week_cos: 0.009
# is_weekend: 0.009
# week_of_month_cos: 0.009
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3375
# MAPE: 50.6542%
# WAPE: 30.1156%
# Validation metrics for fold 1:
# MAE: 0.3326
# MAPE: 55.5018%
# WAPE: 32.7547%
# Top 15 Feature importances:
# avg_peak_7d: 0.553
# avg_peak_3d: 0.172
# max_peak_3d: 0.048
# consumption_sum: 0.040
# consumption_peak: 0.037
# max_peak_7d: 0.036
# same_day_last_week_peak: 0.017
# prev_day_peak: 0.013
# day_of_week_sin: 0.011
# consumption_min: 0.010
# day_of_week_cos: 0.010
# is_weekend: 0.009
# is_summer: 0.009
# is_holiday: 0.009
# week_of_month_cos: 0.009
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3336
# MAPE: 45.4411%
# WAPE: 29.7677%
# Validation metrics for fold 1:
# MAE: 0.3308
# MAPE: 49.4016%
# WAPE: 32.5783%
# Top 15 Feature importances:
# avg_peak_7d: 0.537
# avg_peak_3d: 0.171
# consumption_sum: 0.055
# consumption_peak: 0.050
# max_peak_7d: 0.035
# max_peak_3d: 0.030
# same_day_last_week_peak: 0.017
# prev_day_peak: 0.013
# day_of_week_sin: 0.012
# consumption_min: 0.011
# day_of_week_cos: 0.011
# is_weekend: 0.010
# is_winter: 0.010
# is_summer: 0.010
# week_of_month_sin: 0.010
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3299
# MAPE: 41.5093%
# WAPE: 29.4313%
# Validation metrics for fold 1:
# MAE: 0.3297
# MAPE: 46.3293%
# WAPE: 32.4639%
# Top 15 Feature importances:
# avg_peak_7d: 0.504
# avg_peak_3d: 0.197
# consumption_peak: 0.099
# consumption_sum: 0.036
# max_peak_7d: 0.020
# same_day_last_week_peak: 0.015
# max_peak_3d: 0.013
# day_of_week_sin: 0.013
# prev_day_peak: 0.013
# consumption_min: 0.012
# day_of_week_cos: 0.012
# is_weekend: 0.012
# week_of_month_cos: 0.011
# is_winter: 0.011
# week_of_month_sin: 0.011
#
#
# Fold 2
# Training period: 2013-01-08 to 2013-09-30
# Validation period: 2013-10-01 to 2013-10-31
#
# Target: consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3328
# MAPE: 56.4306%
# WAPE: 30.0111%
# Validation metrics for fold 2:
# MAE: 0.3535
# MAPE: 67.7407%
# WAPE: 32.0884%
# Top 15 Feature importances:
# avg_peak_7d: 0.459
# avg_peak_3d: 0.218
# max_peak_7d: 0.072
# max_peak_3d: 0.058
# consumption_sum: 0.040
# consumption_peak: 0.026
# same_day_last_week_peak: 0.020
# prev_day_peak: 0.014
# day_of_week_sin: 0.014
# is_winter: 0.011
# is_summer: 0.010
# consumption_min: 0.009
# day_of_week_cos: 0.009
# week_of_month_cos: 0.009
# is_weekend: 0.009
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3411
# MAPE: 51.7495%
# WAPE: 30.7615%
# Validation metrics for fold 2:
# MAE: 0.3487
# MAPE: 57.7263%
# WAPE: 31.6547%
# Top 15 Feature importances:
# avg_peak_7d: 0.557
# avg_peak_3d: 0.181
# consumption_sum: 0.058
# consumption_peak: 0.042
# max_peak_7d: 0.029
# max_peak_3d: 0.027
# same_day_last_week_peak: 0.018
# day_of_week_sin: 0.010
# prev_day_peak: 0.010
# consumption_min: 0.009
# day_of_week_cos: 0.008
# is_summer: 0.008
# is_weekend: 0.007
# is_winter: 0.007
# week_of_month_sin: 0.007
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3320
# MAPE: 45.2726%
# WAPE: 29.9359%
# Validation metrics for fold 2:
# MAE: 0.3478
# MAPE: 51.5550%
# WAPE: 31.5683%
# Top 15 Feature importances:
# avg_peak_7d: 0.533
# avg_peak_3d: 0.173
# consumption_sum: 0.054
# consumption_peak: 0.051
# max_peak_7d: 0.035
# max_peak_3d: 0.028
# same_day_last_week_peak: 0.016
# prev_day_peak: 0.013
# day_of_week_sin: 0.012
# consumption_min: 0.011
# day_of_week_cos: 0.010
# is_weekend: 0.010
# is_summer: 0.010
# is_winter: 0.009
# is_holiday: 0.009
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3283
# MAPE: 41.5988%
# WAPE: 29.6056%
# Validation metrics for fold 2:
# MAE: 0.3467
# MAPE: 47.7499%
# WAPE: 31.4713%
# Top 15 Feature importances:
# avg_peak_7d: 0.481
# avg_peak_3d: 0.204
# consumption_peak: 0.105
# consumption_sum: 0.038
# max_peak_7d: 0.020
# same_day_last_week_peak: 0.015
# max_peak_3d: 0.013
# day_of_week_sin: 0.013
# prev_day_peak: 0.013
# consumption_min: 0.013
# day_of_week_cos: 0.012
# is_weekend: 0.011
# week_of_month_sin: 0.011
# is_winter: 0.011
# is_holiday: 0.011
#
#
# Fold 3
# Training period: 2013-01-08 to 2013-10-31
# Validation period: 2013-11-01 to 2013-11-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3344
# MAPE: 57.6575%
# WAPE: 30.1795%
# Validation metrics for fold 3:
# MAE: 0.3829
# MAPE: 54.9899%
# WAPE: 30.4998%
# Top 15 Feature importances:
# avg_peak_7d: 0.459
# avg_peak_3d: 0.219
# max_peak_7d: 0.071
# max_peak_3d: 0.058
# consumption_sum: 0.040
# consumption_peak: 0.026
# same_day_last_week_peak: 0.020
# prev_day_peak: 0.014
# day_of_week_sin: 0.014
# is_winter: 0.010
# is_summer: 0.010
# consumption_min: 0.009
# is_weekend: 0.009
# day_of_week_cos: 0.009
# week_of_month_cos: 0.008
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3362
# MAPE: 50.9253%
# WAPE: 30.3358%
# Validation metrics for fold 3:
# MAE: 0.3790
# MAPE: 48.3143%
# WAPE: 30.1883%
# Top 15 Feature importances:
# avg_peak_7d: 0.541
# avg_peak_3d: 0.173
# max_peak_3d: 0.047
# consumption_sum: 0.041
# max_peak_7d: 0.039
# consumption_peak: 0.039
# same_day_last_week_peak: 0.017
# day_of_week_sin: 0.012
# prev_day_peak: 0.012
# consumption_min: 0.010
# day_of_week_cos: 0.010
# is_weekend: 0.010
# is_summer: 0.009
# week_of_month_cos: 0.009
# week_of_month_sin: 0.008
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3353
# MAPE: 46.1231%
# WAPE: 30.2549%
# Validation metrics for fold 3:
# MAE: 0.3781
# MAPE: 44.4055%
# WAPE: 30.1111%
# Top 15 Feature importances:
# avg_peak_7d: 0.558
# avg_peak_3d: 0.220
# consumption_peak: 0.056
# consumption_sum: 0.035
# max_peak_7d: 0.015
# same_day_last_week_peak: 0.014
# day_of_week_sin: 0.011
# prev_day_peak: 0.010
# max_peak_3d: 0.010
# is_weekend: 0.009
# consumption_min: 0.009
# is_summer: 0.009
# day_of_week_cos: 0.009
# week_of_month_cos: 0.008
# is_holiday: 0.008
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3242
# MAPE: 40.9219%
# WAPE: 29.2594%
# Validation metrics for fold 3:
# MAE: 0.3773
# MAPE: 42.2117%
# WAPE: 30.0533%
# Top 15 Feature importances:
# avg_peak_7d: 0.469
# avg_peak_3d: 0.172
# consumption_peak: 0.112
# consumption_sum: 0.067
# max_peak_3d: 0.033
# max_peak_7d: 0.026
# same_day_last_week_peak: 0.017
# prev_day_peak: 0.012
# day_of_week_sin: 0.012
# consumption_min: 0.010
# is_weekend: 0.010
# day_of_week_cos: 0.010
# is_summer: 0.009
# week_of_month_cos: 0.008
# is_holiday: 0.008
#
#
#
# Results for consumption_peak_next_day:
# Average Training MAE across folds: 0.3335
# Average Training MAPE across folds: 56.9102%
# Average Training WAPE across folds: 29.9714%
# Average Validation MAE across folds: 0.3579
# Average Validation MAPE across folds: 62.1932%
# Average Validation WAPE across folds: 31.9314%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.459
# avg_peak_3d: 0.219
# max_peak_7d: 0.072
# max_peak_3d: 0.059
# consumption_sum: 0.040
# consumption_peak: 0.026
# same_day_last_week_peak: 0.020
# prev_day_peak: 0.015
# day_of_week_sin: 0.014
# is_winter: 0.011
# is_summer: 0.010
# consumption_min: 0.009
# day_of_week_cos: 0.009
# is_weekend: 0.009
# week_of_month_cos: 0.009
#
# Results for log_consumption_peak_next_day:
# Average Training MAE across folds: 0.3383
# Average Training MAPE across folds: 51.1096%
# Average Training WAPE across folds: 30.4043%
# Average Validation MAE across folds: 0.3535
# Average Validation MAPE across folds: 53.8475%
# Average Validation WAPE across folds: 31.5326%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.551
# avg_peak_3d: 0.176
# consumption_sum: 0.046
# max_peak_3d: 0.040
# consumption_peak: 0.039
# max_peak_7d: 0.035
# same_day_last_week_peak: 0.017
# prev_day_peak: 0.012
# day_of_week_sin: 0.011
# consumption_min: 0.009
# day_of_week_cos: 0.009
# is_weekend: 0.009
# is_summer: 0.009
# week_of_month_cos: 0.008
# week_of_month_sin: 0.008
#
# Results for sqrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.3336
# Average Training MAPE across folds: 45.6123%
# Average Training WAPE across folds: 29.9862%
# Average Validation MAE across folds: 0.3522
# Average Validation MAPE across folds: 48.4540%
# Average Validation WAPE across folds: 31.4192%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.542
# avg_peak_3d: 0.188
# consumption_peak: 0.052
# consumption_sum: 0.048
# max_peak_7d: 0.028
# max_peak_3d: 0.023
# same_day_last_week_peak: 0.016
# prev_day_peak: 0.012
# day_of_week_sin: 0.012
# consumption_min: 0.010
# day_of_week_cos: 0.010
# is_weekend: 0.010
# is_summer: 0.009
# is_winter: 0.009
# week_of_month_sin: 0.009
#
# Results for cbrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.3275
# Average Training MAPE across folds: 41.3433%
# Average Training WAPE across folds: 29.4321%
# Average Validation MAE across folds: 0.3512
# Average Validation MAPE across folds: 45.4303%
# Average Validation WAPE across folds: 31.3295%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.484
# avg_peak_3d: 0.191
# consumption_peak: 0.105
# consumption_sum: 0.047
# max_peak_7d: 0.022
# max_peak_3d: 0.020
# same_day_last_week_peak: 0.016
# day_of_week_sin: 0.013
# prev_day_peak: 0.013
# consumption_min: 0.012
# day_of_week_cos: 0.011
# is_weekend: 0.011
# is_summer: 0.010
# week_of_month_cos: 0.010
# is_winter: 0.010
#
# Metrics on test set for consumption_peak_next_day:
# MAE: 0.3936
# MAPE: 65.0182%
# WAPE: 30.7272%
# Metrics on test set for log_consumption_peak_next_day:
# MAE: 0.3865
# MAPE: 57.1380%
# WAPE: 30.1728%
# Metrics on test set for sqrt_consumption_peak_next_day:
# MAE: 0.3860
# MAPE: 50.8990%
# WAPE: 30.1404%
# Metrics on test set for cbrt_consumption_peak_next_day:
# MAE: 0.3835
# MAPE: 48.6112%
# WAPE: 29.9416%
# --- Running Model 2 ---
#
# Fold 1
# Training period: 2013-01-08 to 2013-08-31
# Validation period: 2013-09-01 to 2013-09-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3435
# MAPE: 60.0674%
# WAPE: 30.6436%
# Validation metrics for fold 1:
# MAE: 0.3377
# MAPE: 64.7982%
# WAPE: 33.2545%
# Top 15 Feature importances:
# avg_peak_7d: 0.676
# avg_peak_3d: 0.144
# consumption_sum: 0.019
# consumption_peak: 0.015
# max_peak_7d: 0.013
# same_day_last_week_peak: 0.011
# day_of_week_sin: 0.010
# prev_day_peak: 0.007
# temp_range: 0.007
# temp_max: 0.006
# is_holiday: 0.006
# max_peak_3d: 0.006
# solarradiation_at_peak_consumption: 0.005
# solarradiation_sum: 0.005
# consumption_min: 0.005
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3414
# MAPE: 52.0048%
# WAPE: 30.4570%
# Validation metrics for fold 1:
# MAE: 0.3325
# MAPE: 54.9068%
# WAPE: 32.7466%
# Top 15 Feature importances:
# avg_peak_7d: 0.476
# avg_peak_3d: 0.300
# consumption_sum: 0.038
# consumption_peak: 0.034
# max_peak_7d: 0.018
# same_day_last_week_peak: 0.014
# day_of_week_sin: 0.008
# prev_day_peak: 0.007
# max_peak_3d: 0.007
# solarradiation_at_peak_consumption: 0.006
# consumption_min: 0.006
# is_weekend: 0.006
# is_winter: 0.006
# temp_range: 0.006
# day_of_week_cos: 0.006
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3356
# MAPE: 46.3510%
# WAPE: 29.9450%
# Validation metrics for fold 1:
# MAE: 0.3308
# MAPE: 49.4924%
# WAPE: 32.5748%
# Top 15 Feature importances:
# avg_peak_7d: 0.675
# avg_peak_3d: 0.138
# consumption_peak: 0.042
# consumption_sum: 0.023
# max_peak_7d: 0.009
# same_day_last_week_peak: 0.009
# day_of_week_sin: 0.007
# max_peak_3d: 0.006
# consumption_min: 0.006
# prev_day_peak: 0.006
# solarradiation_at_peak_consumption: 0.005
# is_weekend: 0.005
# temp_range: 0.005
# is_summer: 0.005
# temp_max: 0.004
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3399
# MAPE: 44.3581%
# WAPE: 30.3279%
# Validation metrics for fold 1:
# MAE: 0.3307
# MAPE: 46.0958%
# WAPE: 32.5668%
# Top 15 Feature importances:
# avg_peak_7d: 0.651
# consumption_peak: 0.109
# consumption_sum: 0.063
# avg_peak_3d: 0.059
# same_day_last_week_peak: 0.011
# day_of_week_sin: 0.009
# prev_day_peak: 0.008
# solarradiation_at_peak_consumption: 0.006
# max_peak_7d: 0.006
# is_weekend: 0.006
# consumption_min: 0.006
# temp_range: 0.005
# day_of_week_cos: 0.005
# max_peak_3d: 0.005
# week_of_month_sin: 0.004
#
#
# Fold 2
# Training period: 2013-01-08 to 2013-09-30
# Validation period: 2013-10-01 to 2013-10-31
#
# Target: consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3427
# MAPE: 59.8600%
# WAPE: 30.9024%
# Validation metrics for fold 2:
# MAE: 0.3541
# MAPE: 70.3389%
# WAPE: 32.1436%
# Top 15 Feature importances:
# avg_peak_7d: 0.672
# avg_peak_3d: 0.148
# consumption_sum: 0.020
# consumption_peak: 0.016
# max_peak_7d: 0.012
# same_day_last_week_peak: 0.011
# day_of_week_sin: 0.010
# prev_day_peak: 0.007
# temp_range: 0.006
# is_holiday: 0.006
# temp_max: 0.006
# max_peak_3d: 0.006
# is_winter: 0.005
# solarradiation_at_peak_consumption: 0.005
# precip_sum: 0.005
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3340
# MAPE: 50.0903%
# WAPE: 30.1180%
# Validation metrics for fold 2:
# MAE: 0.3487
# MAPE: 56.9701%
# WAPE: 31.6535%
# Top 15 Feature importances:
# avg_peak_7d: 0.742
# consumption_peak: 0.036
# consumption_sum: 0.025
# avg_peak_3d: 0.018
# day_of_week_sin: 0.010
# same_day_last_week_peak: 0.010
# max_peak_7d: 0.009
# consumption_min: 0.008
# prev_day_peak: 0.008
# is_holiday: 0.008
# max_peak_3d: 0.008
# solarradiation_at_peak_consumption: 0.008
# is_summer: 0.007
# temp_range: 0.007
# is_weekend: 0.007
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3367
# MAPE: 46.6443%
# WAPE: 30.3639%
# Validation metrics for fold 2:
# MAE: 0.3475
# MAPE: 51.7116%
# WAPE: 31.5432%
# Top 15 Feature importances:
# avg_peak_7d: 0.462
# avg_peak_3d: 0.290
# consumption_peak: 0.051
# consumption_sum: 0.039
# max_peak_7d: 0.017
# same_day_last_week_peak: 0.014
# day_of_week_sin: 0.009
# prev_day_peak: 0.007
# max_peak_3d: 0.007
# solarradiation_at_peak_consumption: 0.006
# consumption_min: 0.006
# day_of_week_cos: 0.006
# temp_range: 0.006
# is_weekend: 0.006
# is_winter: 0.005
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3199
# MAPE: 40.1152%
# WAPE: 28.8442%
# Validation metrics for fold 2:
# MAE: 0.3465
# MAPE: 48.2269%
# WAPE: 31.4512%
# Top 15 Feature importances:
# avg_peak_7d: 0.563
# consumption_peak: 0.098
# avg_peak_3d: 0.066
# consumption_sum: 0.027
# day_of_week_sin: 0.012
# same_day_last_week_peak: 0.012
# max_peak_7d: 0.012
# consumption_min: 0.011
# prev_day_peak: 0.011
# day_of_week_cos: 0.010
# is_weekend: 0.010
# max_peak_3d: 0.010
# solarradiation_at_peak_consumption: 0.010
# temp_range: 0.009
# solarradiation_sum: 0.009
#
#
# Fold 3
# Training period: 2013-01-08 to 2013-10-31
# Validation period: 2013-11-01 to 2013-11-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3485
# MAPE: 60.7796%
# WAPE: 31.4484%
# Validation metrics for fold 3:
# MAE: 0.3871
# MAPE: 57.9334%
# WAPE: 30.8308%
# Top 15 Feature importances:
# avg_peak_7d: 0.438
# avg_peak_3d: 0.297
# consumption_sum: 0.074
# consumption_peak: 0.024
# same_day_last_week_peak: 0.023
# max_peak_7d: 0.022
# max_peak_3d: 0.021
# day_of_week_sin: 0.018
# is_winter: 0.007
# prev_day_peak: 0.006
# day_of_week_cos: 0.006
# solarradiation_at_peak_consumption: 0.006
# temp_range: 0.005
# temp_max: 0.004
# week_of_month_cos: 0.004
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3388
# MAPE: 51.3423%
# WAPE: 30.5748%
# Validation metrics for fold 3:
# MAE: 0.3807
# MAPE: 50.2583%
# WAPE: 30.3245%
# Top 15 Feature importances:
# avg_peak_7d: 0.740
# consumption_sum: 0.055
# consumption_peak: 0.041
# avg_peak_3d: 0.029
# day_of_week_sin: 0.015
# same_day_last_week_peak: 0.015
# max_peak_7d: 0.008
# prev_day_peak: 0.007
# solarradiation_at_peak_consumption: 0.007
# is_summer: 0.006
# is_weekend: 0.005
# temp_range: 0.005
# day_of_week_cos: 0.005
# week_of_month_cos: 0.005
# temp_max: 0.004
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3423
# MAPE: 48.1121%
# WAPE: 30.8848%
# Validation metrics for fold 3:
# MAE: 0.3803
# MAPE: 45.3314%
# WAPE: 30.2887%
# Top 15 Feature importances:
# avg_peak_7d: 0.718
# consumption_peak: 0.067
# avg_peak_3d: 0.053
# consumption_sum: 0.051
# same_day_last_week_peak: 0.015
# day_of_week_sin: 0.010
# max_peak_7d: 0.007
# prev_day_peak: 0.007
# solarradiation_at_peak_consumption: 0.006
# temp_range: 0.005
# day_of_week_cos: 0.004
# temp_max: 0.004
# consumption_min: 0.004
# is_weekend: 0.004
# week_of_month_cos: 0.003
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3209
# MAPE: 40.3236%
# WAPE: 28.9535%
# Validation metrics for fold 3:
# MAE: 0.3783
# MAPE: 42.9528%
# WAPE: 30.1299%
# Top 15 Feature importances:
# avg_peak_7d: 0.567
# consumption_peak: 0.095
# avg_peak_3d: 0.066
# consumption_sum: 0.028
# day_of_week_sin: 0.012
# same_day_last_week_peak: 0.012
# max_peak_7d: 0.012
# is_weekend: 0.011
# consumption_min: 0.011
# prev_day_peak: 0.010
# day_of_week_cos: 0.010
# max_peak_3d: 0.010
# solarradiation_at_peak_consumption: 0.009
# week_of_month_sin: 0.009
# is_holiday: 0.009
#
#
#
# Results for consumption_peak_next_day:
# Average Training MAE across folds: 0.3449
# Average Training MAPE across folds: 60.2357%
# Average Training WAPE across folds: 30.9981%
# Average Validation MAE across folds: 0.3596
# Average Validation MAPE across folds: 64.3568%
# Average Validation WAPE across folds: 32.0763%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.595
# avg_peak_3d: 0.196
# consumption_sum: 0.038
# consumption_peak: 0.018
# max_peak_7d: 0.016
# same_day_last_week_peak: 0.015
# day_of_week_sin: 0.013
# max_peak_3d: 0.011
# prev_day_peak: 0.007
# temp_range: 0.006
# is_winter: 0.006
# solarradiation_at_peak_consumption: 0.006
# temp_max: 0.005
# day_of_week_cos: 0.005
# is_holiday: 0.005
#
# Results for log_consumption_peak_next_day:
# Average Training MAE across folds: 0.3381
# Average Training MAPE across folds: 51.1458%
# Average Training WAPE across folds: 30.3833%
# Average Validation MAE across folds: 0.3540
# Average Validation MAPE across folds: 54.0451%
# Average Validation WAPE across folds: 31.5749%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.653
# avg_peak_3d: 0.116
# consumption_sum: 0.039
# consumption_peak: 0.037
# same_day_last_week_peak: 0.013
# max_peak_7d: 0.012
# day_of_week_sin: 0.011
# prev_day_peak: 0.007
# solarradiation_at_peak_consumption: 0.007
# max_peak_3d: 0.006
# consumption_min: 0.006
# is_weekend: 0.006
# temp_range: 0.006
# is_summer: 0.006
# day_of_week_cos: 0.006
#
# Results for sqrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.3382
# Average Training MAPE across folds: 47.0358%
# Average Training WAPE across folds: 30.3979%
# Average Validation MAE across folds: 0.3529
# Average Validation MAPE across folds: 48.8451%
# Average Validation WAPE across folds: 31.4689%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.618
# avg_peak_3d: 0.160
# consumption_peak: 0.053
# consumption_sum: 0.038
# same_day_last_week_peak: 0.012
# max_peak_7d: 0.011
# day_of_week_sin: 0.009
# prev_day_peak: 0.007
# solarradiation_at_peak_consumption: 0.006
# max_peak_3d: 0.006
# consumption_min: 0.005
# temp_range: 0.005
# day_of_week_cos: 0.005
# is_weekend: 0.005
# temp_max: 0.005
#
# Results for cbrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.3269
# Average Training MAPE across folds: 41.5989%
# Average Training WAPE across folds: 29.3752%
# Average Validation MAE across folds: 0.3518
# Average Validation MAPE across folds: 45.7585%
# Average Validation WAPE across folds: 31.3826%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.594
# consumption_peak: 0.101
# avg_peak_3d: 0.064
# consumption_sum: 0.039
# same_day_last_week_peak: 0.011
# day_of_week_sin: 0.011
# prev_day_peak: 0.010
# max_peak_7d: 0.010
# consumption_min: 0.009
# is_weekend: 0.009
# day_of_week_cos: 0.009
# max_peak_3d: 0.008
# solarradiation_at_peak_consumption: 0.008
# temp_range: 0.008
# week_of_month_sin: 0.008
#
# Metrics on test set for consumption_peak_next_day:
# MAE: 0.3977
# MAPE: 65.4365%
# WAPE: 31.0477%
# Metrics on test set for log_consumption_peak_next_day:
# MAE: 0.3912
# MAPE: 56.9194%
# WAPE: 30.5467%
# Metrics on test set for sqrt_consumption_peak_next_day:
# MAE: 0.3887
# MAPE: 52.0977%
# WAPE: 30.3478%
# Metrics on test set for cbrt_consumption_peak_next_day:
# MAE: 0.3865
# MAPE: 49.6987%
# WAPE: 30.1740%
# --- Running Model 3 ---
#
# Fold 1
# Training period: 2013-01-08 to 2013-08-31
# Validation period: 2013-09-01 to 2013-09-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.2839
# MAPE: 48.1370%
# WAPE: 25.3292%
# Validation metrics for fold 1:
# MAE: 0.3273
# MAPE: 67.5115%
# WAPE: 32.2302%
# Top 15 Feature importances:
# avg_peak_7d: 0.355
# avg_peak_3d: 0.094
# max_peak_3d: 0.027
# consumption_sum: 0.019
# max_peak_7d: 0.017
# consumption_peak: 0.015
# uses_electric_heater: 0.012
# ironing_fixed_schedule: 0.010
# tumble_dryer_ownership: 0.010
# immersion_water_heater_fixed_schedule: 0.009
# count_kitchen_appliances: 0.009
# day_of_week_sin: 0.008
# same_day_last_week_peak: 0.008
# prev_day_peak: 0.008
# washing_machine_timer_use: 0.008
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.2756
# MAPE: 39.4580%
# WAPE: 24.5921%
# Validation metrics for fold 1:
# MAE: 0.3205
# MAPE: 55.2706%
# WAPE: 31.5642%
# Top 15 Feature importances:
# avg_peak_7d: 0.334
# avg_peak_3d: 0.085
# consumption_peak: 0.026
# consumption_sum: 0.022
# max_peak_3d: 0.019
# max_peak_7d: 0.015
# uses_electric_heater: 0.014
# tumble_dryer_ownership: 0.012
# count_kitchen_appliances: 0.011
# household_size: 0.009
# same_day_last_week_peak: 0.009
# immersion_water_heater_fixed_schedule: 0.009
# day_of_week_sin: 0.008
# washing_machine_timer_use: 0.008
# prev_day_peak: 0.008
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.2738
# MAPE: 36.0958%
# WAPE: 24.4277%
# Validation metrics for fold 1:
# MAE: 0.3184
# MAPE: 49.9566%
# WAPE: 31.3581%
# Top 15 Feature importances:
# avg_peak_7d: 0.335
# avg_peak_3d: 0.086
# consumption_peak: 0.030
# consumption_sum: 0.028
# max_peak_3d: 0.019
# uses_electric_heater: 0.014
# count_kitchen_appliances: 0.011
# tumble_dryer_ownership: 0.011
# max_peak_7d: 0.010
# immersion_water_heater_fixed_schedule: 0.009
# same_day_last_week_peak: 0.009
# household_size: 0.009
# day_of_week_sin: 0.008
# washing_machine_timer_use: 0.008
# prev_day_peak: 0.008
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.2906
# MAPE: 35.7088%
# WAPE: 25.9320%
# Validation metrics for fold 1:
# MAE: 0.3182
# MAPE: 45.1686%
# WAPE: 31.3294%
# Top 15 Feature importances:
# avg_peak_7d: 0.329
# avg_peak_3d: 0.098
# consumption_peak: 0.062
# consumption_sum: 0.032
# max_peak_3d: 0.020
# uses_electric_heater: 0.012
# max_peak_7d: 0.011
# tumble_dryer_ownership: 0.010
# count_kitchen_appliances: 0.010
# same_day_last_week_peak: 0.009
# household_size: 0.008
# immersion_water_heater_fixed_schedule: 0.008
# prev_day_peak: 0.007
# count_cooking_appliances: 0.007
# day_of_week_sin: 0.007
#
#
# Fold 2
# Training period: 2013-01-08 to 2013-09-30
# Validation period: 2013-10-01 to 2013-10-31
#
# Target: consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3093
# MAPE: 52.1624%
# WAPE: 27.8882%
# Validation metrics for fold 2:
# MAE: 0.3418
# MAPE: 61.8541%
# WAPE: 31.0249%
# Top 15 Feature importances:
# avg_peak_7d: 0.357
# avg_peak_3d: 0.100
# max_peak_3d: 0.025
# consumption_sum: 0.022
# max_peak_7d: 0.017
# consumption_peak: 0.015
# tumble_dryer_ownership: 0.012
# uses_electric_heater: 0.012
# ironing_fixed_schedule: 0.010
# same_day_last_week_peak: 0.010
# count_kitchen_appliances: 0.010
# immersion_water_heater_fixed_schedule: 0.009
# day_of_week_sin: 0.009
# household_size: 0.008
# prev_day_peak: 0.008
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.2776
# MAPE: 39.8870%
# WAPE: 25.0351%
# Validation metrics for fold 2:
# MAE: 0.3344
# MAPE: 52.1421%
# WAPE: 30.3554%
# Top 15 Feature importances:
# avg_peak_7d: 0.335
# avg_peak_3d: 0.086
# consumption_sum: 0.027
# consumption_peak: 0.026
# max_peak_3d: 0.021
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.012
# count_kitchen_appliances: 0.011
# max_peak_7d: 0.010
# same_day_last_week_peak: 0.009
# household_size: 0.009
# immersion_water_heater_fixed_schedule: 0.008
# day_of_week_sin: 0.008
# washing_machine_timer_use: 0.008
# heating_not_sure: 0.007
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.2763
# MAPE: 36.6671%
# WAPE: 24.9168%
# Validation metrics for fold 2:
# MAE: 0.3336
# MAPE: 48.4970%
# WAPE: 30.2794%
# Top 15 Feature importances:
# avg_peak_7d: 0.332
# avg_peak_3d: 0.088
# consumption_peak: 0.033
# consumption_sum: 0.029
# max_peak_3d: 0.019
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.012
# count_kitchen_appliances: 0.011
# max_peak_7d: 0.010
# same_day_last_week_peak: 0.009
# household_size: 0.009
# immersion_water_heater_fixed_schedule: 0.008
# day_of_week_sin: 0.008
# washing_machine_timer_use: 0.008
# electric_central_heating: 0.008
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.2901
# MAPE: 35.9072%
# WAPE: 26.1599%
# Validation metrics for fold 2:
# MAE: 0.3336
# MAPE: 45.5096%
# WAPE: 30.2879%
# Top 15 Feature importances:
# avg_peak_7d: 0.322
# avg_peak_3d: 0.100
# consumption_peak: 0.064
# consumption_sum: 0.033
# max_peak_3d: 0.020
# uses_electric_heater: 0.012
# max_peak_7d: 0.011
# count_kitchen_appliances: 0.011
# tumble_dryer_ownership: 0.010
# household_size: 0.009
# same_day_last_week_peak: 0.009
# prev_day_peak: 0.007
# count_cooking_appliances: 0.007
# washing_machine_timer_use: 0.007
# day_of_week_sin: 0.007
#
#
# Fold 3
# Training period: 2013-01-08 to 2013-10-31
# Validation period: 2013-11-01 to 2013-11-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.2845
# MAPE: 48.5547%
# WAPE: 25.6699%
# Validation metrics for fold 3:
# MAE: 0.3698
# MAPE: 52.4436%
# WAPE: 29.4574%
# Top 15 Feature importances:
# avg_peak_7d: 0.347
# avg_peak_3d: 0.092
# max_peak_3d: 0.027
# consumption_sum: 0.019
# max_peak_7d: 0.017
# consumption_peak: 0.015
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.011
# ironing_fixed_schedule: 0.010
# count_kitchen_appliances: 0.010
# immersion_water_heater_fixed_schedule: 0.009
# day_of_week_sin: 0.009
# same_day_last_week_peak: 0.008
# washing_machine_timer_use: 0.008
# household_size: 0.008
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.2818
# MAPE: 40.7810%
# WAPE: 25.4336%
# Validation metrics for fold 3:
# MAE: 0.3655
# MAPE: 45.6484%
# WAPE: 29.1093%
# Top 15 Feature importances:
# avg_peak_7d: 0.337
# avg_peak_3d: 0.088
# consumption_sum: 0.027
# consumption_peak: 0.027
# max_peak_3d: 0.019
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.012
# count_kitchen_appliances: 0.011
# max_peak_7d: 0.011
# household_size: 0.009
# same_day_last_week_peak: 0.009
# day_of_week_sin: 0.009
# immersion_water_heater_fixed_schedule: 0.008
# electric_central_heating: 0.008
# washing_machine_timer_use: 0.008
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.2802
# MAPE: 37.2949%
# WAPE: 25.2853%
# Validation metrics for fold 3:
# MAE: 0.3647
# MAPE: 42.7910%
# WAPE: 29.0482%
# Top 15 Feature importances:
# avg_peak_7d: 0.336
# avg_peak_3d: 0.085
# consumption_peak: 0.034
# consumption_sum: 0.028
# max_peak_3d: 0.019
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.012
# count_kitchen_appliances: 0.011
# max_peak_7d: 0.011
# household_size: 0.009
# same_day_last_week_peak: 0.009
# day_of_week_sin: 0.008
# immersion_water_heater_fixed_schedule: 0.008
# electric_central_heating: 0.008
# washing_machine_timer_use: 0.008
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.2919
# MAPE: 36.1358%
# WAPE: 26.3397%
# Validation metrics for fold 3:
# MAE: 0.3649
# MAPE: 40.8961%
# WAPE: 29.0638%
# Top 15 Feature importances:
# avg_peak_7d: 0.324
# avg_peak_3d: 0.101
# consumption_peak: 0.062
# consumption_sum: 0.033
# max_peak_3d: 0.020
# uses_electric_heater: 0.012
# max_peak_7d: 0.011
# tumble_dryer_ownership: 0.011
# count_kitchen_appliances: 0.011
# household_size: 0.009
# same_day_last_week_peak: 0.009
# prev_day_peak: 0.007
# day_of_week_sin: 0.007
# immersion_water_heater_fixed_schedule: 0.007
# count_cooking_appliances: 0.007
#
#
#
# Results for consumption_peak_next_day:
# Average Training MAE across folds: 0.2925
# Average Training MAPE across folds: 49.6180%
# Average Training WAPE across folds: 26.2958%
# Average Validation MAE across folds: 0.3463
# Average Validation MAPE across folds: 60.6031%
# Average Validation WAPE across folds: 30.9041%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.353
# avg_peak_3d: 0.095
# max_peak_3d: 0.026
# consumption_sum: 0.020
# max_peak_7d: 0.017
# consumption_peak: 0.015
# uses_electric_heater: 0.012
# tumble_dryer_ownership: 0.011
# ironing_fixed_schedule: 0.010
# count_kitchen_appliances: 0.009
# immersion_water_heater_fixed_schedule: 0.009
# day_of_week_sin: 0.009
# same_day_last_week_peak: 0.009
# household_size: 0.008
# prev_day_peak: 0.008
#
# Results for log_consumption_peak_next_day:
# Average Training MAE across folds: 0.2784
# Average Training MAPE across folds: 40.0420%
# Average Training WAPE across folds: 25.0203%
# Average Validation MAE across folds: 0.3401
# Average Validation MAPE across folds: 51.0203%
# Average Validation WAPE across folds: 30.3430%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.335
# avg_peak_3d: 0.086
# consumption_peak: 0.026
# consumption_sum: 0.026
# max_peak_3d: 0.020
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.012
# max_peak_7d: 0.012
# count_kitchen_appliances: 0.011
# household_size: 0.009
# same_day_last_week_peak: 0.009
# immersion_water_heater_fixed_schedule: 0.009
# day_of_week_sin: 0.008
# washing_machine_timer_use: 0.008
# electric_central_heating: 0.007
#
# Results for sqrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.2768
# Average Training MAPE across folds: 36.6860%
# Average Training WAPE across folds: 24.8766%
# Average Validation MAE across folds: 0.3389
# Average Validation MAPE across folds: 47.0815%
# Average Validation WAPE across folds: 30.2286%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.334
# avg_peak_3d: 0.086
# consumption_peak: 0.033
# consumption_sum: 0.028
# max_peak_3d: 0.019
# uses_electric_heater: 0.014
# tumble_dryer_ownership: 0.011
# count_kitchen_appliances: 0.011
# max_peak_7d: 0.010
# same_day_last_week_peak: 0.009
# household_size: 0.009
# immersion_water_heater_fixed_schedule: 0.009
# day_of_week_sin: 0.008
# washing_machine_timer_use: 0.008
# electric_central_heating: 0.008
#
# Results for cbrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.2909
# Average Training MAPE across folds: 35.9172%
# Average Training WAPE across folds: 26.1439%
# Average Validation MAE across folds: 0.3389
# Average Validation MAPE across folds: 43.8581%
# Average Validation WAPE across folds: 30.2270%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.325
# avg_peak_3d: 0.099
# consumption_peak: 0.062
# consumption_sum: 0.033
# max_peak_3d: 0.020
# uses_electric_heater: 0.012
# max_peak_7d: 0.011
# tumble_dryer_ownership: 0.010
# count_kitchen_appliances: 0.010
# same_day_last_week_peak: 0.009
# household_size: 0.009
# prev_day_peak: 0.007
# immersion_water_heater_fixed_schedule: 0.007
# day_of_week_sin: 0.007
# count_cooking_appliances: 0.007
#
# Metrics on test set for consumption_peak_next_day:
# MAE: 0.3835
# MAPE: 63.5759%
# WAPE: 29.9428%
# Metrics on test set for log_consumption_peak_next_day:
# MAE: 0.3771
# MAPE: 55.8346%
# WAPE: 29.4439%
# Metrics on test set for sqrt_consumption_peak_next_day:
# MAE: 0.3758
# MAPE: 51.4472%
# WAPE: 29.3411%
# Metrics on test set for cbrt_consumption_peak_next_day:
# MAE: 0.3743
# MAPE: 48.8103%
# WAPE: 29.2278%
# --- Running Model 4 (Only Top 15 Features from Model 3) ---
#
# Fold 1
# Training period: 2013-01-08 to 2013-08-31
# Validation period: 2013-09-01 to 2013-09-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3454
# MAPE: 58.9248%
# WAPE: 30.8186%
# Validation metrics for fold 1:
# MAE: 0.3369
# MAPE: 67.1090%
# WAPE: 33.1734%
# Top 15 Feature importances:
# avg_peak_7d: 0.586
# avg_peak_3d: 0.219
# max_peak_7d: 0.047
# consumption_sum: 0.028
# consumption_peak: 0.018
# same_day_last_week_peak: 0.014
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.012
# ironing_fixed_schedule: 0.011
# count_kitchen_appliances: 0.010
# day_of_week_sin: 0.009
# immersion_water_heater_fixed_schedule: 0.009
# washing_machine_timer_use: 0.008
# household_size: 0.008
# max_peak_3d: 0.008
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3132
# MAPE: 45.4596%
# WAPE: 27.9432%
# Validation metrics for fold 1:
# MAE: 0.3295
# MAPE: 54.8598%
# WAPE: 32.4477%
# Top 15 Feature importances:
# avg_peak_7d: 0.436
# avg_peak_3d: 0.190
# consumption_sum: 0.072
# max_peak_7d: 0.053
# consumption_peak: 0.047
# max_peak_3d: 0.031
# uses_electric_heater: 0.026
# same_day_last_week_peak: 0.020
# count_kitchen_appliances: 0.020
# immersion_water_heater_fixed_schedule: 0.020
# tumble_dryer_ownership: 0.020
# household_size: 0.017
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.016
# ironing_fixed_schedule: 0.015
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3338
# MAPE: 45.3943%
# WAPE: 29.7785%
# Validation metrics for fold 1:
# MAE: 0.3287
# MAPE: 49.1631%
# WAPE: 32.3655%
# Top 15 Feature importances:
# avg_peak_7d: 0.705
# avg_peak_3d: 0.080
# consumption_peak: 0.058
# consumption_sum: 0.028
# count_kitchen_appliances: 0.016
# uses_electric_heater: 0.014
# tumble_dryer_ownership: 0.014
# same_day_last_week_peak: 0.013
# max_peak_7d: 0.012
# immersion_water_heater_fixed_schedule: 0.011
# day_of_week_sin: 0.010
# washing_machine_timer_use: 0.010
# household_size: 0.010
# max_peak_3d: 0.009
# ironing_fixed_schedule: 0.009
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 1:
# MAE: 0.3284
# MAPE: 41.7817%
# WAPE: 29.2976%
# Validation metrics for fold 1:
# MAE: 0.3272
# MAPE: 45.7913%
# WAPE: 32.2183%
# Top 15 Feature importances:
# avg_peak_7d: 0.430
# avg_peak_3d: 0.185
# consumption_peak: 0.102
# consumption_sum: 0.094
# max_peak_7d: 0.042
# max_peak_3d: 0.022
# uses_electric_heater: 0.019
# same_day_last_week_peak: 0.016
# count_kitchen_appliances: 0.015
# tumble_dryer_ownership: 0.014
# immersion_water_heater_fixed_schedule: 0.014
# household_size: 0.013
# day_of_week_sin: 0.012
# washing_machine_timer_use: 0.011
# ironing_fixed_schedule: 0.010
#
#
# Fold 2
# Training period: 2013-01-08 to 2013-09-30
# Validation period: 2013-10-01 to 2013-10-31
#
# Target: consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3264
# MAPE: 54.8437%
# WAPE: 29.4346%
# Validation metrics for fold 2:
# MAE: 0.3496
# MAPE: 65.4002%
# WAPE: 31.7357%
# Top 15 Feature importances:
# avg_peak_7d: 0.555
# avg_peak_3d: 0.179
# max_peak_7d: 0.051
# consumption_sum: 0.033
# max_peak_3d: 0.030
# consumption_peak: 0.023
# uses_electric_heater: 0.018
# same_day_last_week_peak: 0.016
# tumble_dryer_ownership: 0.015
# immersion_water_heater_fixed_schedule: 0.015
# ironing_fixed_schedule: 0.014
# count_kitchen_appliances: 0.014
# washing_machine_timer_use: 0.013
# day_of_week_sin: 0.012
# household_size: 0.012
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3134
# MAPE: 45.7930%
# WAPE: 28.2639%
# Validation metrics for fold 2:
# MAE: 0.3453
# MAPE: 55.5405%
# WAPE: 31.3434%
# Top 15 Feature importances:
# avg_peak_7d: 0.440
# avg_peak_3d: 0.187
# consumption_sum: 0.079
# consumption_peak: 0.049
# max_peak_7d: 0.045
# max_peak_3d: 0.031
# uses_electric_heater: 0.024
# count_kitchen_appliances: 0.021
# tumble_dryer_ownership: 0.021
# immersion_water_heater_fixed_schedule: 0.021
# same_day_last_week_peak: 0.020
# household_size: 0.017
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.015
# ironing_fixed_schedule: 0.014
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3109
# MAPE: 41.8782%
# WAPE: 28.0332%
# Validation metrics for fold 2:
# MAE: 0.3447
# MAPE: 49.9748%
# WAPE: 31.2877%
# Top 15 Feature importances:
# avg_peak_7d: 0.429
# avg_peak_3d: 0.183
# consumption_sum: 0.087
# consumption_peak: 0.059
# max_peak_7d: 0.045
# max_peak_3d: 0.028
# uses_electric_heater: 0.025
# count_kitchen_appliances: 0.021
# immersion_water_heater_fixed_schedule: 0.020
# tumble_dryer_ownership: 0.020
# same_day_last_week_peak: 0.020
# household_size: 0.017
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.016
# ironing_fixed_schedule: 0.015
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 2:
# MAE: 0.3272
# MAPE: 42.0079%
# WAPE: 29.5076%
# Validation metrics for fold 2:
# MAE: 0.3442
# MAPE: 46.8225%
# WAPE: 31.2482%
# Top 15 Feature importances:
# avg_peak_7d: 0.426
# avg_peak_3d: 0.186
# consumption_peak: 0.110
# consumption_sum: 0.094
# max_peak_7d: 0.039
# max_peak_3d: 0.024
# uses_electric_heater: 0.018
# same_day_last_week_peak: 0.016
# tumble_dryer_ownership: 0.015
# count_kitchen_appliances: 0.014
# immersion_water_heater_fixed_schedule: 0.014
# household_size: 0.013
# day_of_week_sin: 0.011
# washing_machine_timer_use: 0.010
# ironing_fixed_schedule: 0.009
#
#
# Fold 3
# Training period: 2013-01-08 to 2013-10-31
# Validation period: 2013-11-01 to 2013-11-30
#
# Target: consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3281
# MAPE: 55.6467%
# WAPE: 29.6047%
# Validation metrics for fold 3:
# MAE: 0.3790
# MAPE: 52.0685%
# WAPE: 30.1865%
# Top 15 Feature importances:
# avg_peak_7d: 0.547
# avg_peak_3d: 0.183
# max_peak_7d: 0.053
# consumption_sum: 0.033
# max_peak_3d: 0.030
# consumption_peak: 0.024
# uses_electric_heater: 0.018
# same_day_last_week_peak: 0.016
# tumble_dryer_ownership: 0.015
# immersion_water_heater_fixed_schedule: 0.015
# ironing_fixed_schedule: 0.014
# count_kitchen_appliances: 0.014
# day_of_week_sin: 0.013
# washing_machine_timer_use: 0.013
# household_size: 0.012
#
#
#
# Target: log_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3158
# MAPE: 46.3615%
# WAPE: 28.4987%
# Validation metrics for fold 3:
# MAE: 0.3766
# MAPE: 46.0525%
# WAPE: 29.9963%
# Top 15 Feature importances:
# avg_peak_7d: 0.438
# avg_peak_3d: 0.185
# consumption_sum: 0.064
# max_peak_7d: 0.052
# consumption_peak: 0.048
# max_peak_3d: 0.043
# uses_electric_heater: 0.026
# count_kitchen_appliances: 0.021
# immersion_water_heater_fixed_schedule: 0.021
# tumble_dryer_ownership: 0.020
# same_day_last_week_peak: 0.020
# household_size: 0.017
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.015
# ironing_fixed_schedule: 0.014
#
#
#
# Target: sqrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3135
# MAPE: 42.2390%
# WAPE: 28.2928%
# Validation metrics for fold 3:
# MAE: 0.3759
# MAPE: 43.2877%
# WAPE: 29.9419%
# Top 15 Feature importances:
# avg_peak_7d: 0.430
# avg_peak_3d: 0.181
# consumption_sum: 0.081
# consumption_peak: 0.060
# max_peak_7d: 0.046
# max_peak_3d: 0.035
# uses_electric_heater: 0.026
# tumble_dryer_ownership: 0.020
# count_kitchen_appliances: 0.020
# same_day_last_week_peak: 0.020
# immersion_water_heater_fixed_schedule: 0.019
# household_size: 0.017
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.015
# ironing_fixed_schedule: 0.015
#
#
#
# Target: cbrt_consumption_peak_next_day
# Training metrics for fold 3:
# MAE: 0.3278
# MAPE: 42.0513%
# WAPE: 29.5765%
# Validation metrics for fold 3:
# MAE: 0.3766
# MAPE: 41.4016%
# WAPE: 29.9965%
# Top 15 Feature importances:
# avg_peak_7d: 0.422
# avg_peak_3d: 0.189
# consumption_peak: 0.106
# consumption_sum: 0.095
# max_peak_7d: 0.040
# max_peak_3d: 0.023
# uses_electric_heater: 0.019
# same_day_last_week_peak: 0.016
# tumble_dryer_ownership: 0.016
# count_kitchen_appliances: 0.015
# immersion_water_heater_fixed_schedule: 0.013
# household_size: 0.013
# day_of_week_sin: 0.012
# washing_machine_timer_use: 0.010
# ironing_fixed_schedule: 0.010
#
#
#
# Results for consumption_peak_next_day:
# Average Training MAE across folds: 0.3333
# Average Training MAPE across folds: 56.4717%
# Average Training WAPE across folds: 29.9526%
# Average Validation MAE across folds: 0.3552
# Average Validation MAPE across folds: 61.5259%
# Average Validation WAPE across folds: 31.6985%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.563
# avg_peak_3d: 0.194
# max_peak_7d: 0.050
# consumption_sum: 0.031
# max_peak_3d: 0.023
# consumption_peak: 0.022
# uses_electric_heater: 0.016
# same_day_last_week_peak: 0.015
# tumble_dryer_ownership: 0.014
# immersion_water_heater_fixed_schedule: 0.013
# ironing_fixed_schedule: 0.013
# count_kitchen_appliances: 0.012
# day_of_week_sin: 0.012
# washing_machine_timer_use: 0.011
# household_size: 0.011
#
# Results for log_consumption_peak_next_day:
# Average Training MAE across folds: 0.3141
# Average Training MAPE across folds: 45.8714%
# Average Training WAPE across folds: 28.2353%
# Average Validation MAE across folds: 0.3505
# Average Validation MAPE across folds: 52.1509%
# Average Validation WAPE across folds: 31.2625%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.438
# avg_peak_3d: 0.187
# consumption_sum: 0.072
# max_peak_7d: 0.050
# consumption_peak: 0.048
# max_peak_3d: 0.035
# uses_electric_heater: 0.025
# count_kitchen_appliances: 0.021
# immersion_water_heater_fixed_schedule: 0.020
# tumble_dryer_ownership: 0.020
# same_day_last_week_peak: 0.020
# household_size: 0.017
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.016
# ironing_fixed_schedule: 0.015
#
# Results for sqrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.3194
# Average Training MAPE across folds: 43.1705%
# Average Training WAPE across folds: 28.7015%
# Average Validation MAE across folds: 0.3498
# Average Validation MAPE across folds: 47.4752%
# Average Validation WAPE across folds: 31.1984%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.521
# avg_peak_3d: 0.148
# consumption_sum: 0.066
# consumption_peak: 0.059
# max_peak_7d: 0.034
# max_peak_3d: 0.024
# uses_electric_heater: 0.022
# count_kitchen_appliances: 0.019
# tumble_dryer_ownership: 0.018
# same_day_last_week_peak: 0.017
# immersion_water_heater_fixed_schedule: 0.017
# household_size: 0.014
# day_of_week_sin: 0.014
# washing_machine_timer_use: 0.014
# ironing_fixed_schedule: 0.013
#
# Results for cbrt_consumption_peak_next_day:
# Average Training MAE across folds: 0.3278
# Average Training MAPE across folds: 41.9470%
# Average Training WAPE across folds: 29.4606%
# Average Validation MAE across folds: 0.3493
# Average Validation MAPE across folds: 44.6718%
# Average Validation WAPE across folds: 31.1543%
#
# Top 15 Average feature importances across folds:
# avg_peak_7d: 0.426
# avg_peak_3d: 0.187
# consumption_peak: 0.106
# consumption_sum: 0.094
# max_peak_7d: 0.041
# max_peak_3d: 0.023
# uses_electric_heater: 0.019
# same_day_last_week_peak: 0.016
# tumble_dryer_ownership: 0.015
# count_kitchen_appliances: 0.015
# immersion_water_heater_fixed_schedule: 0.014
# household_size: 0.013
# day_of_week_sin: 0.012
# washing_machine_timer_use: 0.010
# ironing_fixed_schedule: 0.010
#
# Metrics on test set for consumption_peak_next_day:
# MAE: 0.3880
# MAPE: 60.1537%
# WAPE: 30.2910%
# Metrics on test set for log_consumption_peak_next_day:
# MAE: 0.3831
# MAPE: 53.2186%
# WAPE: 29.9093%
# Metrics on test set for sqrt_consumption_peak_next_day:
# MAE: 0.3820
# MAPE: 48.9536%
# WAPE: 29.8232%
# Metrics on test set for cbrt_consumption_peak_next_day:
# MAE: 0.3818
# MAPE: 46.5135%
# WAPE: 29.8116%
# --- Model Comparison ---
#
# Model 1:
# Number of features: 18
#
# Test metrics for consumption_peak_next_day:
#   MAE: 0.3936
#   MAPE: 65.0182%
#   WAPE: 30.7272%
#
# Test metrics for log_consumption_peak_next_day:
#   MAE: 0.3865
#   MAPE: 57.1380%
#   WAPE: 30.1728%
#
# Test metrics for sqrt_consumption_peak_next_day:
#   MAE: 0.3860
#   MAPE: 50.8990%
#   WAPE: 30.1404%
#
# Test metrics for cbrt_consumption_peak_next_day:
#   MAE: 0.3835
#   MAPE: 48.6112%
#   WAPE: 29.9416%
#
# Top 15 Feature Importances:
#
# consumption_peak_next_day:
# avg_peak_7d: 0.457
# avg_peak_3d: 0.220
# max_peak_7d: 0.075
# max_peak_3d: 0.056
# consumption_sum: 0.041
# consumption_peak: 0.027
# same_day_last_week_peak: 0.019
# day_of_week_sin: 0.015
# prev_day_peak: 0.014
# is_summer: 0.010
# is_winter: 0.010
# is_weekend: 0.009
# consumption_min: 0.009
# day_of_week_cos: 0.008
# week_of_month_cos: 0.008
#
# log_consumption_peak_next_day:
# avg_peak_7d: 0.542
# avg_peak_3d: 0.174
# max_peak_3d: 0.048
# consumption_sum: 0.041
# max_peak_7d: 0.039
# consumption_peak: 0.038
# same_day_last_week_peak: 0.017
# day_of_week_sin: 0.012
# prev_day_peak: 0.012
# is_weekend: 0.010
# consumption_min: 0.009
# day_of_week_cos: 0.009
# is_summer: 0.009
# week_of_month_sin: 0.009
# week_of_month_cos: 0.008
#
# sqrt_consumption_peak_next_day:
# avg_peak_7d: 0.576
# avg_peak_3d: 0.214
# consumption_peak: 0.050
# consumption_sum: 0.033
# max_peak_7d: 0.014
# same_day_last_week_peak: 0.013
# day_of_week_sin: 0.011
# max_peak_3d: 0.010
# prev_day_peak: 0.009
# is_weekend: 0.009
# is_summer: 0.009
# day_of_week_cos: 0.008
# consumption_min: 0.008
# week_of_month_sin: 0.008
# week_of_month_cos: 0.007
#
# cbrt_consumption_peak_next_day:
# avg_peak_7d: 0.465
# avg_peak_3d: 0.171
# consumption_peak: 0.114
# consumption_sum: 0.067
# max_peak_3d: 0.033
# max_peak_7d: 0.027
# same_day_last_week_peak: 0.017
# prev_day_peak: 0.013
# day_of_week_sin: 0.013
# is_weekend: 0.010
# consumption_min: 0.010
# day_of_week_cos: 0.010
# is_summer: 0.010
# is_holiday: 0.008
# is_autumn: 0.008
#
# Model 2:
# Number of features: 30
#
# Test metrics for consumption_peak_next_day:
#   MAE: 0.3977
#   MAPE: 65.4365%
#   WAPE: 31.0477%
#
# Test metrics for log_consumption_peak_next_day:
#   MAE: 0.3912
#   MAPE: 56.9194%
#   WAPE: 30.5467%
#
# Test metrics for sqrt_consumption_peak_next_day:
#   MAE: 0.3887
#   MAPE: 52.0977%
#   WAPE: 30.3478%
#
# Test metrics for cbrt_consumption_peak_next_day:
#   MAE: 0.3865
#   MAPE: 49.6987%
#   WAPE: 30.1740%
#
# Top 15 Feature Importances:
#
# consumption_peak_next_day:
# avg_peak_7d: 0.453
# avg_peak_3d: 0.278
# consumption_sum: 0.084
# max_peak_7d: 0.023
# consumption_peak: 0.022
# same_day_last_week_peak: 0.021
# max_peak_3d: 0.020
# day_of_week_sin: 0.019
# is_winter: 0.006
# prev_day_peak: 0.006
# solarradiation_at_peak_consumption: 0.006
# temp_range: 0.005
# day_of_week_cos: 0.005
# is_weekend: 0.005
# temp_max: 0.004
#
# log_consumption_peak_next_day:
# avg_peak_7d: 0.739
# consumption_sum: 0.055
# consumption_peak: 0.043
# avg_peak_3d: 0.029
# same_day_last_week_peak: 0.016
# day_of_week_sin: 0.016
# max_peak_7d: 0.010
# prev_day_peak: 0.007
# solarradiation_at_peak_consumption: 0.006
# day_of_week_cos: 0.006
# week_of_month_sin: 0.005
# temp_range: 0.005
# week_of_month_cos: 0.005
# is_weekend: 0.005
# temp_max: 0.005
#
# sqrt_consumption_peak_next_day:
# avg_peak_7d: 0.709
# consumption_peak: 0.067
# consumption_sum: 0.057
# avg_peak_3d: 0.050
# same_day_last_week_peak: 0.017
# day_of_week_sin: 0.011
# max_peak_7d: 0.007
# prev_day_peak: 0.006
# solarradiation_at_peak_consumption: 0.006
# temp_range: 0.005
# is_weekend: 0.005
# day_of_week_cos: 0.004
# temp_max: 0.004
# consumption_min: 0.004
# max_peak_3d: 0.004
#
# cbrt_consumption_peak_next_day:
# avg_peak_7d: 0.571
# consumption_peak: 0.096
# avg_peak_3d: 0.064
# consumption_sum: 0.028
# day_of_week_sin: 0.012
# same_day_last_week_peak: 0.012
# max_peak_7d: 0.011
# consumption_min: 0.011
# is_weekend: 0.011
# prev_day_peak: 0.010
# max_peak_3d: 0.010
# day_of_week_cos: 0.010
# solarradiation_at_peak_consumption: 0.010
# is_winter: 0.009
# is_autumn: 0.009
#
# Model 3:
# Number of features: 88
#
# Test metrics for consumption_peak_next_day:
#   MAE: 0.3835
#   MAPE: 63.5759%
#   WAPE: 29.9428%
#
# Test metrics for log_consumption_peak_next_day:
#   MAE: 0.3771
#   MAPE: 55.8346%
#   WAPE: 29.4439%
#
# Test metrics for sqrt_consumption_peak_next_day:
#   MAE: 0.3758
#   MAPE: 51.4472%
#   WAPE: 29.3411%
#
# Test metrics for cbrt_consumption_peak_next_day:
#   MAE: 0.3743
#   MAPE: 48.8103%
#   WAPE: 29.2278%
#
# Top 15 Feature Importances:
#
# consumption_peak_next_day:
# avg_peak_7d: 0.341
# avg_peak_3d: 0.093
# max_peak_3d: 0.030
# max_peak_7d: 0.018
# consumption_sum: 0.018
# consumption_peak: 0.015
# uses_electric_heater: 0.013
# tumble_dryer_ownership: 0.010
# count_kitchen_appliances: 0.009
# day_of_week_sin: 0.009
# ironing_fixed_schedule: 0.009
# household_size: 0.008
# same_day_last_week_peak: 0.008
# washing_machine_timer_use: 0.008
# immersion_water_heater_fixed_schedule: 0.008
#
# log_consumption_peak_next_day:
# avg_peak_7d: 0.343
# avg_peak_3d: 0.087
# consumption_peak: 0.027
# consumption_sum: 0.023
# max_peak_3d: 0.019
# max_peak_7d: 0.015
# uses_electric_heater: 0.014
# tumble_dryer_ownership: 0.012
# count_kitchen_appliances: 0.010
# household_size: 0.009
# same_day_last_week_peak: 0.009
# day_of_week_sin: 0.009
# immersion_water_heater_fixed_schedule: 0.008
# washing_machine_timer_use: 0.007
# count_cooking_appliances: 0.007
#
# sqrt_consumption_peak_next_day:
# avg_peak_7d: 0.344
# avg_peak_3d: 0.086
# consumption_peak: 0.034
# consumption_sum: 0.029
# max_peak_3d: 0.019
# uses_electric_heater: 0.014
# tumble_dryer_ownership: 0.012
# max_peak_7d: 0.011
# count_kitchen_appliances: 0.010
# household_size: 0.009
# same_day_last_week_peak: 0.009
# day_of_week_sin: 0.008
# heating_not_sure: 0.008
# electric_central_heating: 0.007
# washing_machine_timer_use: 0.007
#
# cbrt_consumption_peak_next_day:
# avg_peak_7d: 0.329
# avg_peak_3d: 0.100
# consumption_peak: 0.063
# consumption_sum: 0.032
# max_peak_3d: 0.020
# uses_electric_heater: 0.012
# tumble_dryer_ownership: 0.011
# max_peak_7d: 0.011
# count_kitchen_appliances: 0.010
# household_size: 0.009
# same_day_last_week_peak: 0.008
# day_of_week_sin: 0.008
# prev_day_peak: 0.007
# immersion_water_heater_fixed_schedule: 0.007
# housing_house: 0.007
#
# Model 4:
# Number of features: 15
#
# Test metrics for consumption_peak_next_day:
#   MAE: 0.3880
#   MAPE: 60.1537%
#   WAPE: 30.2910%
#
# Test metrics for log_consumption_peak_next_day:
#   MAE: 0.3831
#   MAPE: 53.2186%
#   WAPE: 29.9093%
#
# Test metrics for sqrt_consumption_peak_next_day:
#   MAE: 0.3820
#   MAPE: 48.9536%
#   WAPE: 29.8232%
#
# Test metrics for cbrt_consumption_peak_next_day:
#   MAE: 0.3818
#   MAPE: 46.5135%
#   WAPE: 29.8116%
#
# Top 15 Feature Importances:
#
# consumption_peak_next_day:
# avg_peak_7d: 0.546
# avg_peak_3d: 0.182
# max_peak_7d: 0.053
# consumption_sum: 0.034
# max_peak_3d: 0.031
# consumption_peak: 0.024
# uses_electric_heater: 0.018
# same_day_last_week_peak: 0.016
# immersion_water_heater_fixed_schedule: 0.015
# tumble_dryer_ownership: 0.015
# ironing_fixed_schedule: 0.014
# day_of_week_sin: 0.014
# count_kitchen_appliances: 0.014
# washing_machine_timer_use: 0.013
# household_size: 0.012
#
# log_consumption_peak_next_day:
# avg_peak_7d: 0.439
# avg_peak_3d: 0.189
# consumption_sum: 0.063
# max_peak_7d: 0.051
# consumption_peak: 0.048
# max_peak_3d: 0.043
# uses_electric_heater: 0.025
# immersion_water_heater_fixed_schedule: 0.020
# tumble_dryer_ownership: 0.020
# count_kitchen_appliances: 0.020
# same_day_last_week_peak: 0.019
# household_size: 0.016
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.015
# ironing_fixed_schedule: 0.014
#
# sqrt_consumption_peak_next_day:
# avg_peak_7d: 0.431
# avg_peak_3d: 0.185
# consumption_sum: 0.074
# consumption_peak: 0.057
# max_peak_7d: 0.045
# max_peak_3d: 0.044
# uses_electric_heater: 0.025
# tumble_dryer_ownership: 0.020
# same_day_last_week_peak: 0.019
# immersion_water_heater_fixed_schedule: 0.019
# count_kitchen_appliances: 0.019
# household_size: 0.016
# day_of_week_sin: 0.016
# washing_machine_timer_use: 0.015
# ironing_fixed_schedule: 0.014
#
# cbrt_consumption_peak_next_day:
# avg_peak_7d: 0.430
# avg_peak_3d: 0.184
# consumption_peak: 0.106
# consumption_sum: 0.096
# max_peak_7d: 0.040
# max_peak_3d: 0.021
# uses_electric_heater: 0.019
# same_day_last_week_peak: 0.016
# tumble_dryer_ownership: 0.016
# count_kitchen_appliances: 0.015
# household_size: 0.013
# immersion_water_heater_fixed_schedule: 0.013
# day_of_week_sin: 0.012
# washing_machine_timer_use: 0.010
# ironing_fixed_schedule: 0.009

# %%
# Get the best hyperparameters for the cube root transformation of Model 4 (the best performing model)
best_params_cbrt_model4 = model_4['cbrt_consumption_peak_next_day'].get_params()
# Filter only the tuned hyperparameters
tuned_params = ['n_estimators', 'max_depth', 'learning_rate', 'subsample', 'colsample_bytree', 'min_child_weight', 'gamma', 'reg_alpha', 'reg_lambda']

print("\nBest tuned hyperparameters for cube root transformation of Model 4:")
for param in tuned_params:
    print(f"{param}: {best_params_cbrt_model4[param]}")
# Out:
# Best tuned hyperparameters for cube root transformation of Model 4:
# n_estimators: 1270
# max_depth: 8
# learning_rate: 0.018057171166114286
# subsample: 0.7390362533589154
# colsample_bytree: 0.7292919068542159
# min_child_weight: 5
# gamma: 0.05667096138379524
# reg_alpha: 0.45240482674645155
# reg_lambda: 0.4500867470007611
